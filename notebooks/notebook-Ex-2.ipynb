# %%
from datetime import datetime

def get_time(city: str) -> str:
  """Get the current time."""
  current_time = datetime.now()
  return f"{current_time} in {city}"

# %%
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"


# Verify the tool works independently before giving it to the agent
print(get_weather("Lahore"))
# Out:
# It's always sunny in Lahore!

# %% [markdown]
# # With 0.0 temperature

# %%
from langchain.agents import create_agent
from langchain_ollama import ChatOllama

llm = ChatOllama(
  model="minimax-m2.5:cloud",
  temperature=0.0,
)

agent = create_agent(
  model=llm,
  tools=[get_weather, get_time],
  system_prompt="You are a helpful assistant.",
)

response = agent.invoke(
  {"messages":[{"role":"user", "content":"What is the weather and current time in Islamabad?"}]}
)

print(response["messages"][-1].content)
# Out:
# The weather in Islamabad is sunny, and the current time is 2026-03-10 11:52:06.364064.

# %% [markdown]
# # With Temperature of 1.0

# %%
from langchain.agents import create_agent
from langchain_ollama import ChatOllama

llm = ChatOllama(
  model="minimax-m2.5:cloud",
  temperature=1.0,
)

agent = create_agent(
  model=llm,
  tools=[get_weather, get_time],
  system_prompt="You are a helpful assistant.",
)

response = agent.invoke(
  {"messages":[{"role":"user", "content":"What is the weather and current time in Islamabad?"}]}
)

print(response["messages"][-1].content)
# Out:
# The current time in Islamabad is 11:53:02 and the weather is sunny.
